# %%
## randomly generate
## (4n)/N
## if x^2+y^2 <=1

import random

points = {}
n = 0
total =1000000
for i in range(0,total+1):
    x = 2*random.random()-1
    y= 2*random.random()-1

    points[x]=y

    if x**2+y**2<=1:
        n+=1


print((4*n)/total)
# Out:
# 3.141484

# %%
letters = {}

sentence = "all happy families are alike each unhappy family is unhappy in its own way"

for letter in sentence:
    if letter in letters.keys():
        letters[letter]+=1
    else:
        letters[letter]=1

alphabet = "abcdefghijklmnopqrstuvwxyz"
for letter in alphabet:
    if letter in letters.keys():
        print(letter, ":",letters[letter])
##print(letters)
# Out:
# a : 10
# c : 1
# e : 4
# f : 2
# h : 4
# i : 7
# k : 1
# l : 5
# m : 2
# n : 4
# o : 1
# p : 6
# r : 1
# s : 3
# t : 1
# u : 2
# w : 2
# y : 5

# %%
paragraph = "It was the best of times, it was the worst of times, it was the age of wisdom, it was the age of foolishness, it was the epoch of belief, it was the epoch of incredulity, it was the season of Light, it was the season of Darkness, it was the spring of hope, it was the winter of despair, we had everything before us, we had nothing before us, we were all going direct to Heaven, we were all going direct the other way – in short, the period was so far like the present period, that some of its noisiest authorities insisted on its being received, for good or for evil, in the superlative degree of comparison only."

words = {}
paragraph=paragraph.lower()
word_list = []

for word in paragraph.split():
    if word[-1] == "," or word[-1]=="." or word[-1]=="-":
        word = word[0:len(word)-1]
    if word in words.keys():
        words[word]+=1
    else:
        words[word]=1
    if(word not in word_list):
        word_list.append(word)

word_list.sort()
for word in word_list:
    print(word, ":", words[word])
##print(words)
# Out:
# age : 2
# all : 2
# authorities : 1
# before : 2
# being : 1
# belief : 1
# best : 1
# comparison : 1
# darkness : 1
# degree : 1
# despair : 1
# direct : 2
# epoch : 2
# everything : 1
# evil : 1
# far : 1
# foolishness : 1
# for : 2
# going : 2
# good : 1
# had : 2
# heaven : 1
# hope : 1
# in : 2
# incredulity : 1
# insisted : 1
# it : 10
# its : 2
# light : 1
# like : 1
# noisiest : 1
# nothing : 1
# of : 12
# on : 1
# only : 1
# or : 1
# other : 1
# period : 2
# present : 1
# received : 1
# season : 2
# short : 1
# so : 1
# some : 1
# spring : 1
# superlative : 1
# that : 1
# the : 14
# times : 2
# to : 1
# us : 2
# was : 11
# way : 1
# we : 4
# were : 2
# winter : 1
# wisdom : 1
# worst : 1
# – : 1

# %%
paragraph = "It was the best of times, it was the worst of times, it was the age of wisdom, it was the age of foolishness, it was the epoch of belief, it was the epoch of incredulity, it was the season of Light, it was the season of Darkness, it was the spring of hope, it was the winter of despair, we had everything before us, we had nothing before us, we were all going direct to Heaven, we were all going direct the other way – in short, the period was so far like the present period, that some of its noisiest authorities insisted on its being received, for good or for evil, in the superlative degree of comparison only."
##i=0
new_paragraph = []
punctuation = ""
for i, word in enumerate(paragraph.split()):
    if word[-1] == "," or word[-1]=="." or word[-1]=="-":
        punctuation = word[-1]
        word = word[0:len(word)-1]
        
    if(i%2==1):
        word = word[::-1]
    
    if punctuation != "":
        word = word + punctuation
    new_paragraph.append(word)
    ##i+=1
    punctuation = ""
print(" ".join(new_paragraph))
# Out:
# It saw the tseb of semit, it saw the tsrow of semit, it saw the ega of modsiw, it saw the ega of ssenhsiloof, it saw the hcope of feileb, it saw the hcope of ytiludercni, it saw the nosaes of thgiL, it saw the nosaes of ssenkraD, it saw the gnirps of epoh, it saw the retniw of riapsed, we dah everything erofeb us, ew had gnihton before su, we erew all gniog direct ot Heaven, ew were lla going tcerid the rehto way – in trohs, the doirep was os far ekil the tneserp period, taht some fo its tseision authorities detsisni on sti being deviecer, for doog or rof evil, ni the evitalrepus degree fo comparison ylno.
